# %% [markdown]
# create a grid with each 2-d coordinate holds its state value as a binary number.

# %%
x_max, y_max = 12, 12

grid=[]
for x in range(x_max):
    for y in range(y_max):
        state = 0
        grid.append({"x": x, "y": y, "state": state})

# %%
for cell in grid:
    x, y = cell.x, cell.y
